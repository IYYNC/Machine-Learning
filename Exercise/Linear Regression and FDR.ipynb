# %% [markdown]
# ## Assignment 1 : Linear Regression and FDR.
# ### BAX 452 Yi Yin "Ian" Chen

# %% [markdown]
# - Importing data

# %%
#Importing pandas
import pandas as pd
import numpy as np
#Importing csv data
df = pd.read_csv('/Users/ianchen/MSBA/BAX452 Machine Learning/Python/fundamentals.csv')
#Count NAs and remove
na_count = df.isna().sum()
print(na＿count)
df_clean = df.dropna()
#Check results
print(df)
print(df_clean)
# Out:
# Unnamed: 0                        0
# Ticker Symbol                     0
# Period Ending                     0
# Accounts Payable                  0
# Accounts Receivable               0
#                                ...
# Total Revenue                     0
# Treasury Stock                    0
# For Year                        173
# Earnings Per Share              219
# Estimated Shares Outstanding    219
# Length: 79, dtype: int64
#       Unnamed: 0 Ticker Symbol Period Ending  Accounts Payable  \
# 0              0           AAL    2012-12-31      3.068000e+09
# 1              1           AAL    2013-12-31      4.975000e+09
# 2              2           AAL    2014-12-31      4.668000e+09
# 3              3           AAL    2015-12-31      5.102000e+09
# 4              4           AAP    2012-12-29      2.409453e+09
# ...          ...           ...           ...               ...
# 1776        1776          ZION    2015-12-31      0.000000e+00
# 1777        1777           ZTS    2013-12-31      1.381000e+09
# 1778        1778           ZTS    2014-12-31      1.071000e+09
# 1779        1779           ZTS    2015-12-31      1.313000e+09
# 1780        1780           ZTS    2016-12-31      1.076000e+09
#
#       Accounts Receivable  Add'l income/expense items  After Tax ROE  \
# 0            -222000000.0               -1.961000e+09           23.0
# 1             -93000000.0               -2.723000e+09           67.0
# 2            -160000000.0               -1.500000e+08          143.0
# 3             352000000.0               -7.080000e+08          135.0
# 4             -89482000.0                6.000000e+05           32.0
# ...                   ...                         ...            ...
# 1776                  0.0               -2.530000e+06            4.0
# 1777          -99000000.0                9.000000e+06           54.0
# 1778           69000000.0               -7.000000e+06           44.0
# 1779          -58000000.0               -8.100000e+07           32.0
# 1780           15000000.0                2.000000e+06           55.0
#
#       Capital Expenditures  Capital Surplus  Cash Ratio  ...  \
# 0            -1.888000e+09     4.695000e+09        53.0  ...
# 1            -3.114000e+09     1.059200e+10        75.0  ...
# 2            -5.311000e+09     1.513500e+10        60.0  ...
# 3            -6.151000e+09     1.159100e+10        51.0  ...
# 4            -2.711820e+08     5.202150e+08        23.0  ...
# ...                    ...              ...         ...  ...
# 1776         -1.573610e+08     0.000000e+00         NaN  ...
# 1777         -1.840000e+08     8.780000e+08        43.0  ...
# 1778         -1.800000e+08     9.580000e+08        81.0  ...
# 1779         -2.240000e+08     1.012000e+09        65.0  ...
# 1780         -2.160000e+08     1.024000e+09        65.0  ...
#
#       Total Current Assets  Total Current Liabilities  Total Equity  \
# 0             7.072000e+09               9.011000e+09 -7.987000e+09
# 1             1.432300e+10               1.380600e+10 -2.731000e+09
# 2             1.175000e+10               1.340400e+10  2.021000e+09
# 3             9.985000e+09               1.360500e+10  5.635000e+09
# 4             3.184200e+09               2.559638e+09  1.210694e+09
# ...                    ...                        ...           ...
# 1776          0.000000e+00               0.000000e+00  7.507519e+09
# 1777          3.357000e+09               1.415000e+09  9.400000e+08
# 1778          3.465000e+09               1.086000e+09  1.311000e+09
# 1779          3.830000e+09               1.781000e+09  1.068000e+09
# 1780          3.390000e+09               1.117000e+09  1.487000e+09
#
#       Total Liabilities  Total Liabilities & Equity  Total Revenue  \
# 0          2.489100e+10                1.690400e+10   2.485500e+10
# 1          4.500900e+10                4.227800e+10   2.674300e+10
# 2          4.120400e+10                4.322500e+10   4.265000e+10
# 3          4.278000e+10                4.841500e+10   4.099000e+10
# 4          3.403120e+09                4.613814e+09   6.205003e+09
# ...                 ...                         ...            ...
# 1776       5.216201e+10                5.966952e+10   2.210591e+09
# 1777       5.618000e+09                6.558000e+09   4.561000e+09
# 1778       5.277000e+09                6.588000e+09   4.785000e+09
# 1779       6.845000e+09                7.913000e+09   4.765000e+09
# 1780       6.162000e+09                7.649000e+09   4.888000e+09
#
#       Treasury Stock  For Year  Earnings Per Share  \
# 0       -367000000.0    2012.0               -5.60
# 1                0.0    2013.0              -11.25
# 2                0.0    2014.0                4.02
# 3                0.0    2015.0               11.39
# 4        -27095000.0    2012.0                5.29
# ...              ...       ...                 ...
# 1776             0.0    2015.0                1.20
# 1777             0.0    2013.0                1.01
# 1778             0.0    2014.0                1.16
# 1779    -203000000.0    2015.0                0.68
# 1780    -421000000.0       NaN                 NaN
#
#       Estimated Shares Outstanding
# 0                     3.350000e+08
# 1                     1.630222e+08
# 2                     7.169154e+08
# 3                     6.681299e+08
# 4                     7.328355e+07
# ...                            ...
# 1776                  2.578925e+08
# 1777                  4.990099e+08
# 1778                  5.025862e+08
# 1779                  4.985294e+08
# 1780                           NaN
#
# [1781 rows x 79 columns]
#       Unnamed: 0 Ticker Symbol Period Ending  Accounts Payable  \
# 0              0           AAL    2012-12-31      3.068000e+09
# 1              1           AAL    2013-12-31      4.975000e+09
# 2              2           AAL    2014-12-31      4.668000e+09
# 3              3           AAL    2015-12-31      5.102000e+09
# 4              4           AAP    2012-12-29      2.409453e+09
# ...          ...           ...           ...               ...
# 1771        1771           ZBH    2014-12-31      2.255000e+08
# 1772        1772           ZBH    2015-12-31      4.320000e+08
# 1777        1777           ZTS    2013-12-31      1.381000e+09
# 1778        1778           ZTS    2014-12-31      1.071000e+09
# 1779        1779           ZTS    2015-12-31      1.313000e+09
#
#       Accounts Receivable  Add'l income/expense items  After Tax ROE  \
# 0            -222000000.0               -1.961000e+09           23.0
# 1             -93000000.0               -2.723000e+09           67.0
# 2            -160000000.0               -1.500000e+08          143.0
# 3             352000000.0               -7.080000e+08          135.0
# 4             -89482000.0                6.000000e+05           32.0
# ...                   ...                         ...            ...
# 1771          -40400000.0               -3.480000e+07           11.0
# 1772          -56100000.0               -2.750000e+07            1.0
# 1777          -99000000.0                9.000000e+06           54.0
# 1778           69000000.0               -7.000000e+06           44.0
# 1779          -58000000.0               -8.100000e+07           32.0
#
#       Capital Expenditures  Capital Surplus  Cash Ratio  ...  \
# 0            -1.888000e+09     4.695000e+09        53.0  ...
# 1            -3.114000e+09     1.059200e+10        75.0  ...
# 2            -5.311000e+09     1.513500e+10        60.0  ...
# 3            -6.151000e+09     1.159100e+10        51.0  ...
# 4            -2.711820e+08     5.202150e+08        23.0  ...
# ...                    ...              ...         ...  ...
# 1771         -3.423000e+08     4.330700e+09       166.0  ...
# 1772         -4.341000e+08     8.195300e+09       100.0  ...
# 1777         -1.840000e+08     8.780000e+08        43.0  ...
# 1778         -1.800000e+08     9.580000e+08        81.0  ...
# 1779         -2.240000e+08     1.012000e+09        65.0  ...
#
#       Total Current Assets  Total Current Liabilities  Total Equity  \
# 0             7.072000e+09               9.011000e+09 -7.987000e+09
# 1             1.432300e+10               1.380600e+10 -2.731000e+09
# 2             1.175000e+10               1.340400e+10  2.021000e+09
# 3             9.985000e+09               1.360500e+10  5.635000e+09
# 4             3.184200e+09               2.559638e+09  1.210694e+09
# ...                    ...                        ...           ...
# 1771          4.313300e+09               1.024000e+09  6.549900e+09
# 1772          5.862900e+09               1.617900e+09  9.887900e+09
# 1777          3.357000e+09               1.415000e+09  9.400000e+08
# 1778          3.465000e+09               1.086000e+09  1.311000e+09
# 1779          3.830000e+09               1.781000e+09  1.068000e+09
#
#       Total Liabilities  Total Liabilities & Equity  Total Revenue  \
# 0          2.489100e+10                1.690400e+10   2.485500e+10
# 1          4.500900e+10                4.227800e+10   2.674300e+10
# 2          4.120400e+10                4.322500e+10   4.265000e+10
# 3          4.278000e+10                4.841500e+10   4.099000e+10
# 4          3.403120e+09                4.613814e+09   6.205003e+09
# ...                 ...                         ...            ...
# 1771       3.108100e+09                9.658000e+09   4.673300e+09
# 1772       1.733160e+10                2.721950e+10   5.997800e+09
# 1777       5.618000e+09                6.558000e+09   4.561000e+09
# 1778       5.277000e+09                6.588000e+09   4.785000e+09
# 1779       6.845000e+09                7.913000e+09   4.765000e+09
#
#       Treasury Stock  For Year  Earnings Per Share  \
# 0      -3.670000e+08    2012.0               -5.60
# 1       0.000000e+00    2013.0              -11.25
# 2       0.000000e+00    2014.0                4.02
# 3       0.000000e+00    2015.0               11.39
# 4      -2.709500e+07    2012.0                5.29
# ...              ...       ...                 ...
# 1771   -6.183700e+09    2014.0                4.26
# 1772   -6.329100e+09    2015.0                0.78
# 1777    0.000000e+00    2013.0                1.01
# 1778    0.000000e+00    2014.0                1.16
# 1779   -2.030000e+08    2015.0                0.68
#
#       Estimated Shares Outstanding
# 0                     3.350000e+08
# 1                     1.630222e+08
# 2                     7.169154e+08
# 3                     6.681299e+08
# 4                     7.328355e+07
# ...                            ...
# 1771                  1.690845e+08
# 1772                  1.884615e+08
# 1777                  4.990099e+08
# 1778                  5.025862e+08
# 1779                  4.985294e+08
#
# [1299 rows x 79 columns]

# %% [markdown]
# ### 1. Data Exploration and Visualization: Explore the “fundamentals.csv”. Include any other plots you find interesting. (10 pts)

# %%
#Import package for plotting
import matplotlib.pyplot as plt
#Drop unused columns for plotting
df_plot = df_clean.drop(['Unnamed: 0', 'Ticker Symbol', 'Period Ending'], axis = 1)
x_vars = ['Earnings Before Interest and Tax','Net Cash Flow','Operating Income','Total Assets','Total Liabilities & Equity','Total Revenue','Earnings Per Share']
y_vars = ['Estimated Shares Outstanding']
#Loop scatter plots for each variable chosen against Estimated Shares Outstanding
for i in x_vars:
    for j in y_vars:
        plt.scatter(df_plot[i], df_plot[j])
        plt.xlabel(i)
        plt.ylabel(j)
        plt.title(f"Scatter Plot {i} vs {j}")
        plt.show()
#After analyzing the scatter plots, pick out the variables that are clustered to plot box-plot for further analysis
box_var = ['Earnings Before Interest and Tax','Net Cash Flow','Operating Income','Earnings Per Share']
for i in box_var:
    plt.figure(figsize=(10, 5))
    plt.boxplot(df_plot[i])
    plt.xlabel(i)
    plt.title(f"Boxplot for {i}")
    plt.show()
#Plot Histograms too
for i in box_var:
    plt.figure(figsize=(10, 5))
    plt.hist(df_plot[i], bins=100, edgecolor='black', alpha=0.7)
    plt.title(f"Histogram of {i}")
    plt.xlabel(i)
    plt.ylabel("Frequency")
    plt.show()

# %% [markdown]
# ### Insights
# The original data has 1781 observations and 78 attributes.
#
# The NA values for each attribute is as follows:
#
# - For Year: 173
#
# - Cash Ratio: 299
#
# - Current Ratio: 299
#
# - Quick Ratio: 299
#
# - Earnings Per Share: 219
#
# - Estimated Shares Outstanding: 219
#
# After removing the NA values, the cleaned data has 1299 observations and 78 attributes
#
# After examining the whole dataset and attributes, I selected a few variables that seemed logical to analyze against Estimated Shares Outstanding(y variable).
#
# I then plotted these variables against y in scatter plots to futher examine. From the plots shown, it is obvious that EBIT, Operating Income, Total Assets, Total Liabilities & Equity and Total Revenue is showing decent relationships with the y variable, which is logical because these variables all somehow represent how a company is performing financialy and thus has a positive relation to the Estimated Shares Outstanding.
#
# As for Net Cash flow and EPS, it seems that the data is clustered around 0. The same could be seen in some of the other variables which shown relations.
# To further analyze the distriburion of these variables, boxplots and histograms served the purpose well, we can see that for variables like EPS, Net Cash Flow, Operating Income and EBIT, data has a centeral tendency possibly due to the nature of the stock market and how companies operate, all of these are shown to cluster in the middle despite certain amount of outliers.

# %% [markdown]
# ### 2. Linear Regression Model Development: Create linear regression to predict Estimated Shares Outstanding. Explain your model. (15 pts)

# %% [markdown]
# - Import statsmodels for regression

# %%
import statsmodels.formula.api as smf

# %%
#Clean column names with special characters and spaces
df = df_plot
df.columns = df.columns.str.replace(' ','_')
df.columns = df.columns.str.replace(',','')
df.columns = df.columns.str.replace('/','_')
df.columns = df.columns.str.replace("'",'')
df.columns = df.columns.str.replace('.','')
df.columns = df.columns.str.replace("&","and")
df.columns = df.columns.str.replace('-','_')
#Prepare the regression formula for the ols model
formula = 'Estimated_Shares_Outstanding ~' + ' + '.join(df.columns.difference(['Estimated_Shares_Outstanding']))
#Run the ols model
ols_full_model = smf.ols(formula=formula, data = df_plot).fit()
full_model_output = ols_full_model.summary()
#Show the output
full_model_output
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ========================================================================================
# Dep. Variable:     Estimated_Shares_Outstanding   R-squared:                       0.854
# Model:                                      OLS   Adj. R-squared:                  0.846
# Method:                           Least Squares   F-statistic:                     98.40
# Date:                          Mon, 22 Jan 2024   Prob (F-statistic):               0.00
# Time:                                  22:21:52   Log-Likelihood:                -27507.
# No. Observations:                          1299   AIC:                         5.516e+04
# Df Residuals:                              1225   BIC:                         5.554e+04
# Df Model:                                    73
# Covariance Type:                      nonrobust
# =======================================================================================================================
#                                                           coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------
# Intercept                                            7.312e+08      1e+09      0.729      0.466   -1.24e+09     2.7e+09
# Accounts_Payable                                     -183.9454    238.959     -0.770      0.442    -652.760     284.869
# Accounts_Receivable                                    -0.0722      0.057     -1.274      0.203      -0.183       0.039
# Addl_income_expense_items                               0.0361      0.057      0.635      0.525      -0.075       0.148
# After_Tax_ROE                                       -6.663e+05      5e+05     -1.332      0.183   -1.65e+06    3.15e+05
# Net_Income_Adjustments                                 -0.0835      0.053     -1.565      0.118      -0.188       0.021
# Net_Income_Applicable_to_Common_Shareholders           -0.1929      0.198     -0.974      0.330      -0.582       0.196
# Net_Income_Cont_Operations                              0.1151      0.062      1.844      0.065      -0.007       0.237
# Net_Receivables                                        -1.2667      0.617     -2.052      0.040      -2.478      -0.055
# Non_Recurring_Items                                     0.0457      0.022      2.097      0.036       0.003       0.088
# Operating_Income                                        0.1820      0.058      3.147      0.002       0.069       0.295
# Operating_Margin                                    -8.032e+06   2.05e+06     -3.916      0.000   -1.21e+07   -4.01e+06
# Other_Assets                                           -0.0390      0.989     -0.039      0.969      -1.980       1.902
# Other_Current_Assets                                   -1.2380      0.618     -2.004      0.045      -2.450      -0.026
# Other_Current_Liabilities                            -183.9494    238.959     -0.770      0.442    -652.763     284.865
# Other_Equity                                            0.0057      0.012      0.465      0.642      -0.018       0.030
# Other_Financing_Activities                              0.0729      0.034      2.170      0.030       0.007       0.139
# Other_Investing_Activities                              0.8695      2.397      0.363      0.717      -3.833       5.572
# Other_Liabilities                                       0.0333      0.099      0.336      0.737      -0.161       0.227
# Other_Operating_Activities                             -0.0985      0.057     -1.721      0.086      -0.211       0.014
# Other_Operating_Items                                   0.0266      0.025      1.055      0.292      -0.023       0.076
# Pre_Tax_Margin                                       9.413e+06   2.77e+06      3.402      0.001    3.99e+06    1.48e+07
# Pre_Tax_ROE                                          4.397e+05   3.39e+05      1.295      0.196   -2.26e+05    1.11e+06
# Profit_Margin                                       -3.036e+06   2.99e+06     -1.016      0.310    -8.9e+06    2.83e+06
# Quick_Ratio                                         -3.744e+05   4.43e+05     -0.845      0.398   -1.24e+06    4.95e+05
# Research_and_Development                                0.0826      0.022      3.719      0.000       0.039       0.126
# Retained_Earnings                                      -0.0097      0.009     -1.075      0.283      -0.027       0.008
# Sale_and_Purchase_of_Stock                              0.1254      0.021      5.960      0.000       0.084       0.167
# Sales_General_and_Admin                                 0.0127      0.013      0.940      0.347      -0.014       0.039
# Short_Term_Debt___Current_Portion_of_Long_Term_Debt  -183.8769    238.959     -0.769      0.442    -652.692     284.938
# Short_Term_Investments                                 -1.2200      0.617     -1.977      0.048      -2.431      -0.009
# Total_Assets                                            0.0386      0.992      0.039      0.969      -1.907       1.984
# Total_Current_Assets                                    1.2034      1.160      1.037      0.300      -1.073       3.480
# Total_Current_Liabilities                             183.9484    238.959      0.770      0.442    -284.867     652.763
# Total_Equity                                        -3605.7518   4944.316     -0.729      0.466   -1.33e+04    6094.513
# Total_Liabilities                                   -3605.7967   4944.317     -0.729      0.466   -1.33e+04    6094.472
# Total_Liabilities_and_Equity                         3605.7905   4944.318      0.729      0.466   -6094.479    1.33e+04
# Total_Revenue                                       -1729.6768   2371.821     -0.729      0.466   -6382.957    2923.604
# Treasury_Stock                                         -0.0074      0.009     -0.807      0.420      -0.025       0.011
# ==============================================================================
# Omnibus:                     1262.725   Durbin-Watson:                   1.564
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           238833.437
# Skew:                           3.999   Prob(JB):                         0.00
# Kurtosis:                      68.944   Cond. No.                     1.17e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.17e+16. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
import numpy as np
#Calculate RMSE
predictions_full = ols_full_model.predict(df.drop('Estimated_Shares_Outstanding', axis = 1))
residuals = df['Estimated_Shares_Outstanding']-predictions_full
#Calculate MSE
mse = np.mean(residuals**2)
#Calculate RMSE
rmse = np.sqrt(mse)
rmse
# Out:
# 380263471.15317816

# %%
#Find the predictors that have significant p-value under 0.05 significance level
#Extract the pvalues and coefficients from the model
pvalues = ols_full_model.pvalues
coefficients = ols_full_model.params
extract = pd.DataFrame({'Coefficient': coefficients,'pvalue': pvalues}).reset_index()
#Select predictors with pvalues <= 0.05
significant_p = extract[extract['pvalue']<= 0.05]
significant_p
# Out:
#                          index   Coefficient        pvalue
# 8    Cash_and_Cash_Equivalents -1.238828e+00  4.484996e-02
# 18          Earnings_Per_Share -3.087098e+07  7.831145e-27
# 26                  Income_Tax  1.561858e-01  1.931908e-02
# 29                   Inventory -1.254831e+00  4.254612e-02
# 35                 Misc_Stocks  3.429781e-01  1.200947e-02
# 36              Net_Borrowings  1.033327e-01  5.861265e-07
# 39    Net_Cash_Flows_Financing -2.019483e-01  2.623028e-02
# 45             Net_Receivables -1.266714e+00  4.042291e-02
# 46         Non_Recurring_Items  4.565924e-02  3.622031e-02
# 47            Operating_Income  1.820131e-01  1.686630e-03
# 48            Operating_Margin -8.032155e+06  9.510752e-05
# 50        Other_Current_Assets -1.238016e+00  4.528280e-02
# 53  Other_Financing_Activities  7.293007e-02  3.023459e-02
# 58              Pre_Tax_Margin  9.413336e+06  6.898272e-04
# 62    Research_and_Development  8.255572e-02  2.091825e-04
# 64  Sale_and_Purchase_of_Stock  1.253887e-01  3.285409e-09
# 67      Short_Term_Investments -1.219992e+00  4.826868e-02

# %% [markdown]
# ### Insights & Interpretation
# - The model's R-squared value is 0.854, indicating that apporximately 85.4% of the variance in the Estimated Shares Outstanding can be explained by the full model.
#
# - The overal F-statistic is 98.4 and its p-value is signigicantly low, indicating the full model might be a good fit not considering other factors like multicollinearity.
#
# - The p-values for Cash and Cash Equivalents, Earnings Per Share, Income Tax, Inventory, Misc Stocks, Net Borrowings, Net Cash Flows Financing, Net Receivables, Non Recurring Items, Operating Income, Operating Margin, Other Current Assets, Other Financing Activites, Pre Tax Margin, Research and Development, Sale and Purchase of Stock and Short Term Investments are significant at the 0.05 significance level, suggesting the listed predictors have a significant effect on Estimated Shares Outstanding.
#
# - The other predictors does not show signigicance at the 0.05 level, implying that with other variables held constant, they do not provide significant predictive power to the Estimated Shares Outstanding.
#
# - The Intercept is around 731 million, suggesting that with every thing else held constant, this is the baseline amount of outstanding shares for a given company listed.
#
# - The coefficients for the significant predictors can be interpreted as, holding other predictors constant, each unit change in the predictar would result to the corresponding coefficient value change in the Estimated Shares Outstanding.

# %% [markdown]
# ### 3. Multicollinearity in Linear Regression: Explain how multicollinearity can affect the interpretation of a linear regression model's coefficients. (Written) (10 pts)

# %% [markdown]
# ### Answer
# Multicollinearity in Linear Regression can cause several problems when we are trying to draw inferential analysis from the model, especially in a model with multiple variables like this one. A few things multicollinearity can impact the coefficients are as follows.
#
# - The coefficients tend to be unstable, any changes in our data could lead to a signigicant change in the coefficients, this leaves the interpretation of the coefficients of little use when multicollinearity is high in a model.
#
# - The p-values of the predictors might show statistically insignificant even if it actually is an important predictor, this leads to the difficulty of identifying the important predictors and their individual effect on the dependent variable.
#
# - Though multicollinearity is not a huge concern when predicting the dependent variable, it still makes interpreting the model and the coefficients of the predictors highly difficult.
#
# - The attribution of the effect to the coefficients might be incorrect and biased, making it hard to single out which variable is driving the change.

# %% [markdown]
# ### 4. P-Value Analysis and Histogram: Create a histogram of the p-values. Is there any skewedness? Provide your explanation. (10 pts)

# %%
#Plot histogram from the p-values extracted
plt.hist(extract.iloc[1:]['pvalue'], bins=50, edgecolor='black', alpha=0.7)
plt.title("Histogram of p-values")
plt.xlabel("p-value")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Insights
# The p-values from the full model viewed in a histogram view shows several noticeable skewness.
#
# - The overall distribution shows slightly right skewed, having the highest peak near 0.
#
# - There is also a significant peak just below 0.5
#
# - Histogram also shows a peak near 1.0.
#
# - The p-values of this model does not show a uniform distribution, as should be when the null hypothesis is true and there is no effect in the predictos, indicating there might be true effects in the model predictors.

# %% [markdown]
# ### 5. False Discovery Rate Control with BH Procedure: Given the p values you find, use the BH procedure to control the FDR with a q of 0.1. How many “true” discoveries do you estimate? (15 pts)

# %%
#Import Numpy
import numpy as np

# %% [markdown]
# Build FDR function

# %%
def fdr(pvals, q, plotit=False):
  # Remove NA values
  pvals = np.array(pvals)
  pvals = pvals[~np.isnan(pvals)]
  N = len(pvals)
  
  # Sort the p-values and calculate the FDR threshold
  sorted_pvals = np.sort(pvals)
  k = np.arange(1, N+1)
  fdr_threshold = (q * k) / N
  
  # Find the last p-value that is below the FDR threshold
  below_threshold = sorted_pvals <= fdr_threshold
  max_index = np.max(np.where(below_threshold)) if np.any(below_threshold) else 0
  alpha = sorted_pvals[max_index]
  print(f"Alpha: {alpha}")
  
  # Optional plot
  if plotit:
    plt.scatter(range(N), sorted_pvals, c=np.where(sorted_pvals <= alpha, 'red', 'grey'), marker='o')
    plt.yscale('log')
    plt.plot(range(N), fdr_threshold, linestyle='--', color='blue')
    plt.xlabel("Tests ordered by p-value")
    plt.ylabel("p-values")
    plt.title(f"FDR = {q}")
    plt.show()
  
  return alpha

# %%
#Prepare the p-values, excluding the intercept
p = extract.iloc[1:]
#Run the FDR function
fdr(p['pvalue'],0.1,plotit=True)
# Out:
# Alpha: 0.0016866300784808
# 0.0016866300784808

# %%
#Count the true discoveries
true = p[p['pvalue']<=0.0016866300784808]
len(true['pvalue'])
# Out:
# 7

# %% [markdown]
# ### True Discovery Estimate
# According to the plot and also the count using the alpha threshold, we can estimate there are 7 true discoveries in the model.

# %% [markdown]
# ### 6. Sensitivity Analysis of FDR Control: If you apply the BH procedure at different q values, how do the results change? What does this tell you about the robustness of your significant variables? (10 pts)

# %%
#Create a list of q values for sensitivity analysis
q_values = np.arange(0.01,1.01,0.01)
#Create empty list to store the alphas
alphas = []
#Run the sensitivity analysis
for i in q_values:
    alphas.append(fdr(p['pvalue'],i))
#Count the pvalues below threshold to double check
true_counts = []
for i in alphas:
    count = len(p[p['pvalue']<=i])
    true_counts.append(count)
# Out:
# Alpha: 0.0006898272422120684
# Alpha: 0.0016866300784808
# Alpha: 0.0016866300784808
# Alpha: 0.0016866300784808
# Alpha: 0.0016866300784808
# Alpha: 0.0016866300784808
# Alpha: 0.0016866300784808
# Alpha: 0.0016866300784808
# Alpha: 0.0016866300784808
# Alpha: 0.0016866300784808
# Alpha: 0
# - According to the plot, the ideal cutoff could be around 0.2 false discovery rate, this shows decent robustness of the variables that are found significant.

# %% [markdown]
# ### 7. Exploring Interaction Terms: (10pts, 5 pts for each)

# %% [markdown]
# ### a. Expand your linear regression model by adding interaction terms. Create interaction terms between pairs of predictors (up to quadratic terms, i.e., terms of power two). You should include both original predictors and their interaction terms in your model.

# %%
#Prepare the cleaned dataframe for model
df = df_plot
df.columns = df.columns.str.replace(' ','_')
df.columns = df.columns.str.replace(',','')
df.columns = df.columns.str.replace('/','_')
df.columns = df.columns.str.replace("'",'')
df.columns = df.columns.str.replace('.','')
df.columns = df.columns.str.replace("&","and")
df.columns = df.columns.str.replace('-','_')

# %%
from sklearn.preprocessing import PolynomialFeatures
#  degree=2 for interaction terms
polynomial_fea = PolynomialFeatures(degree=2, include_bias=False)

# fit and transform the data to create the interaction terms
interaction_fit = polynomial_fea.fit_transform(df.iloc[:, :25])


# feature names for the columns from the Polynomial Features
interaction_features= polynomial_fea.get_feature_names_out(df.iloc[:, :25].columns)

# interaction terms into DataFrame
interactions_df = pd.DataFrame(interaction_fit, columns=interaction_features)
interactions_df
# Out:
#       Accounts_Payable  Accounts_Receivable  Addl_income_expense_items  \
# 0         3.068000e+09         -222000000.0              -1.961000e+09
# 1         4.975000e+09          -93000000.0              -2.723000e+09
# 2         4.668000e+09         -160000000.0              -1.500000e+08
# 3         5.102000e+09          352000000.0              -7.080000e+08
# 4         2.409453e+09          -89482000.0               6.000000e+05
# ...                ...                  ...                        ...
# 1294      2.255000e+08          -40400000.0              -3.480000e+07
# 1295      4.320000e+08          -56100000.0              -2.750000e+07
# 1296      1.381000e+09          -99000000.0               9.000000e+06
# 1297      1.071000e+09           69000000.0              -7.000000e+06
# 1298      1.313000e+09          -58000000.0              -8.100000e+07
#
#       After_Tax_ROE  Capital_Expenditures  Capital_Surplus  Cash_Ratio  \
# 0              23.0         -1.888000e+09     4.695000e+09        53.0
# 1              67.0         -3.114000e+09     1.059200e+10        75.0
# 2             143.0         -5.311000e+09     1.513500e+10        60.0
# 3             135.0         -6.151000e+09     1.159100e+10        51.0
# 4              32.0         -2.711820e+08     5.202150e+08        23.0
# ...             ...                   ...              ...         ...
# 1294           11.0         -3.423000e+08     4.330700e+09       166.0
# 1295            1.0         -4.341000e+08     8.195300e+09       100.0
# 1296           54.0         -1.840000e+08     8.780000e+08        43.0
# 1297           44.0         -1.800000e+08     9.580000e+08        81.0
# 1298           32.0         -2.240000e+08     1.012000e+09        65.0
#
#       Cash_and_Cash_Equivalents  Changes_in_Inventories  Common_Stocks  ...  \
# 0                  1.330000e+09                     0.0    127000000.0  ...
# 1                  2.175000e+09                     0.0      5000000.0  ...
# 2                  1.768000e+09                     0.0      7000000.0  ...
# 3                  1.085000e+09                     0.0      6000000.0  ...
# 4                  5.981110e+08            -260298000.0         7000.0  ...
# ...                         ...                     ...            ...  ...
# 1294               1.083300e+09            -164600000.0      2700000.0  ...
# 1295               1.459300e+09            -205400000.0      3000000.0  ...
# 1296               6.100000e+08            -178000000.0      5000000.0  ...
# 1297               8.820000e+08            -110000000.0      5000000.0  ...
# 1298               1.154000e+09            -262000000.0      5000000.0  ...
#
#       Gross_Margin^2  Gross_Margin Gross_Profit  Gross_Margin Income_Tax  \
# 0             3364.0               8.326480e+11            -3.300200e+10
# 1             3481.0               9.277160e+11            -2.041400e+10
# 2             3969.0               1.702890e+12             2.079000e+10
# 3             5329.0               2.182262e+12            -2.185620e+11
# 4             2500.0               1.549018e+11             1.182020e+10
# ...              ...                        ...                      ...
# 1294          5329.0               2.504265e+11             1.607460e+10
# 1295          4900.0               2.938040e+11             4.900000e+08
# 1296          3969.0               1.821960e+11             1.178100e+10
# 1297          4096.0               1.963520e+11             1.491200e+10
# 1298          4096.0               1.937280e+11             1.318400e+10
#
#       Gross_Margin Intangible_Assets  Gross_Profit^2  Gross_Profit Income_Tax  \
# 0                       5.040200e+10    2.060947e+20            -8.168564e+18
# 1                       1.363490e+11    2.472442e+20            -5.440504e+18
# 2                       1.411200e+11    7.306209e+20             8.919900e+18
# 3                       1.641770e+11    8.936512e+20            -8.950264e+19
# 4                       1.442250e+09    9.597827e+18             7.323881e+17
# ...                              ...             ...                      ...
# 1294                    4.405550e+10    1.176833e+19             7.553961e+17
# 1295                    6.122410e+11    1.761649e+19             2.938040e+16
# 1296                    5.058900e+10    8.363664e+18             5.408040e+17
# 1297                    4.652800e+10    9.412624e+18             7.148440e+17
# 1298                    7.616000e+10    9.162729e+18             6.235620e+17
#
#       Gross_Profit Intangible_Assets  Income_Tax^2  \
# 0                       1.247536e+19  3.237610e+17
# 1                       3.633816e+19  1.197160e+17
# 2                       6.054720e+19  1.089000e+17
# 3                       6.723161e+19  8.964036e+18
# 4                       8.936285e+16  5.588685e+16
# ...                              ...           ...
# 1294                    2.070307e+18  4.848804e+16
# 1295                    3.670997e+19  4.900000e+13
# 1296                    2.322276e+18  3.496900e+16
# 1297                    2.230436e+18  5.428900e+16
# 1298                    3.602130e+18  4.243600e+16
#
#       Income_Tax Intangible_Assets  Intangible_Assets^2
# 0                    -4.944610e+17         7.551610e+17
# 1                    -7.996060e+17         5.340721e+18
# 2                     7.392000e+17         5.017600e+18
# 3                    -6.733506e+18         5.058001e+18
# 4                     6.819073e+15         8.320340e+14
# ...                            ...                  ...
# 1294                  1.328907e+17         3.642122e+17
# 1295                  6.122410e+16         7.649776e+19
# 1296                  1.501610e+17         6.448090e+17
# 1297                  1.693910e+17         5.285290e+17
# 1298                  2.451400e+17         1.416100e+18
#
# [1299 rows x 350 columns]

# %%
import statsmodels.api as sm
x = sm.add_constant(interactions_df.reset_index(drop=True))
y = df['Estimated_Shares_Outstanding'].reset_index(drop=True)

interaction_model = sm.OLS(list(y), x).fit()
print(interaction_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.944
# Model:                            OLS   Adj. R-squared:                  0.926
# Method:                 Least Squares   F-statistic:                     52.58
# Date:                Mon, 22 Jan 2024   Prob (F-statistic):               0.00
# Time:                        22:21:53   Log-Likelihood:                -26886.
# No. Observations:                1299   AIC:                         5.440e+04
# Df Residuals:                     983   BIC:                         5.604e+04
# Df Model:                         315
# Covariance Type:            nonrobust
# ===================================================================================================================================================
#                                                                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------------
# const                                                                               0.0003      0.000      1.342      0.180      -0.000       0.001
# Accounts_Payable                                                                   -0.0753      0.046     -1.653      0.099      -0.165       0.014
# Accounts_Receivable                                                                -0.5266      0.285     -1.850      0.065      -1.085       0.032
# Addl_income_expense_items                                                           0.0584      0.277      0.211      0.833      -0.485       0.602
# After_Tax_ROE                                                                       0.0010      0.001      0.754      0.451      -0.002       0.004
# Capital_Expenditures                                                                0.0195      0.097      0.202      0.840      -0.170       0.209
# Capital_Surplus                                                                     0.0556      0.021      2.667      0.008       0.015       0.097
# Cash_Ratio                                                                          0.0002      0.000      0.470      0.638      -0.001       0.001
# Cash_and_Cash_Equivalents                                                          -0.0240      0.059     -0.406      0.685      -0.140       0.092
# Changes_in_Inventories                                                             -0.1546      0.481     -0.321      0.748      -1.098       0.789
# Common_Stocks                                                                      -0.0115      0.050     -0.233      0.816      -0.109       0.086
# Cost_of_Revenue                                                                    -0.0081      0.009     -0.890      0.373      -0.026       0.010
# Current_Ratio                                                                       0.0010      0.001      1.548      0.122      -0.000       0.002
# Deferred_Asset_Charges                                                              0.2450      0.121      2.020      0.044       0.007       0.483
# Deferred_Liability_Charges                                                         -0.0359      0.059     -0.607      0.544      -0.152       0.080
# Depreciation                                                                        0.0534      0.151      0.353      0.724      -0.244       0.351
# Earnings_Before_Interest_and_Tax                                                    0.4119      0.302      1.365      0.172      -0.180       1.004
# Earnings_Before_Tax                                                                -0.4636      0.295     -1.570      0.117      -1.043       0.116
# Effect_of_Exchange_Rate                                                            -0.0009      0.025     -0.034      0.973      -0.050       0.048
# Equity_Earnings_Loss_Unconsolidated_Subsidiary                                     -0.2081      0.132     -1.581      0.114      -0.466       0.050
# Fixed_Assets                                                                        0.0085      0.020      0.434      0.664      -0.030       0.047
# Goodwill                                                                            0.0614      0.029      2.143      0.032       0.005       0.118
# Gross_Margin                                                                      3.94e-05   5.13e-05      0.768      0.443   -6.13e-05       0.000
# Gross_Profit                                                                        0.0272      0.089      0.306      0.760      -0.147       0.202
# Income_Tax                                                                          0.2818      0.294      0.960      0.337      -0.294       0.858
# Intangible_Assets                                                                  -0.1607      0.044     -3.627      0.000      -0.248      -0.074
# Accounts_Payable^2                                                               4.128e-12   1.92e-12      2.150      0.032     3.6e-13     7.9e-12
# Accounts_Payable Accounts_Receivable                                             6.014e-12   1.72e-11      0.350      0.726   -2.77e-11    3.97e-11
# Accounts_Payable Addl_income_expense_items                                       4.647e-11   4.59e-11      1.013      0.311   -4.36e-11    1.37e-10
# Accounts_Payable After_Tax_ROE                                                      0.0004      0.000      1.477      0.140      -0.000       0.001
# Accounts_Payable Capital_Expenditures                                            4.248e-11   1.68e-11      2.521      0.012    9.42e-12    7.55e-11
# Accounts_Payable Capital_Surplus                                                 9.545e-13   3.53e-12      0.270      0.787   -5.98e-12    7.89e-12
# Accounts_Payable Cash_Ratio                                                         0.0002      0.000      0.510      0.610      -0.001       0.001
# Accounts_Payable Cash_and_Cash_Equivalents                                      -3.842e-12   6.16e-12     -0.624      0.533   -1.59e-11    8.25e-12
# Accounts_Payable Changes_in_Inventories                                          6.285e-13   2.04e-11      0.031      0.975   -3.95e-11    4.08e-11
# Accounts_Payable Common_Stocks                                                  -4.549e-13   5.35e-12     -0.085      0.932    -1.1e-11       1e-11
# Accounts_Payable Cost_of_Revenue                                                -2.518e-12   8.95e-13     -2.814      0.005   -4.27e-12   -7.62e-13
# Accounts_Payable Current_Ratio                                                      0.0004      0.000      1.559      0.119      -0.000       0.001
# Accounts_Payable Deferred_Asset_Charges                                         -1.305e-11   1.39e-11     -0.939      0.348   -4.03e-11    1.42e-11
# Accounts_Payable Deferred_Liability_Charges                                      3.047e-12   1.03e-11      0.295      0.768   -1.72e-11    2.33e-11
# Accounts_Payable Depreciation                                                   -9.446e-11   2.62e-11     -3.604      0.000   -1.46e-10    -4.3e-11
# Accounts_Payable Earnings_Before_Interest_and_Tax                                 -1.8e-10   6.48e-11     -2.778      0.006   -3.07e-10   -5.28e-11
# Accounts_Payable Earnings_Before_Tax                                              1.63e-10    6.5e-11      2.507      0.012    3.54e-11    2.91e-10
# Accounts_Payable Effect_of_Exchange_Rate                                         4.899e-11   9.23e-11      0.531      0.596   -1.32e-10     2.3e-10
# Accounts_Payable Equity_Earnings_Loss_Unconsolidated_Subsidiary                  1.221e-10   8.19e-11      1.491      0.136   -3.86e-11    2.83e-10
# Accounts_Payable Fixed_Assets                                                    1.668e-11    3.4e-12      4.909      0.000       1e-11    2.34e-11
# Accounts_Payable Goodwill                                                        1.333e-12   2.98e-12      0.447      0.655   -4.52e-12    7.19e-12
# Accounts_Payable Gross_Margin                                                      -0.0003      0.000     -0.522      0.602      -0.001       0.001
# Accounts_Payable Gross_Profit                                                    8.698e-12      3e-12      2.897      0.004    2.81e-12    1.46e-11
# Accounts_Payable Income_Tax                                                      4.923e-11   3.55e-11      1.387      0.166   -2.04e-11    1.19e-10
# Accounts_Payable Intangible_Assets                                               6.597e-12   5.37e-12      1.229      0.219   -3.93e-12    1.71e-11
# Accounts_Receivable^2                                                            9.567e-11   3.46e-11      2.767      0.006    2.78e-11    1.64e-10
# Accounts_Receivable Addl_income_expense_items                                   -1.014e-10    1.5e-10     -0.675      0.500   -3.96e-10    1.93e-10
# Accounts_Receivable After_Tax_ROE                                                  -0.0005      0.002     -0.258      0.796      -0.004       0.003
# Accounts_Receivable Capital_Expenditures                                        -1.105e-10   6.89e-11     -1.604      0.109   -2.46e-10    2.47e-11
# Accounts_Receivable Capital_Surplus                                             -2.147e-12   1.23e-11     -0.174      0.862   -2.63e-11     2.2e-11
# Accounts_Receivable Cash_Ratio                                                     -0.0055      0.002     -3.376      0.001      -0.009      -0.002
# Accounts_Receivable Cash_and_Cash_Equivalents                                    1.294e-10   3.04e-11      4.250      0.000    6.96e-11    1.89e-10
# Accounts_Receivable Changes_in_Inventories                                      -6.294e-12   1.12e-10     -0.056      0.955   -2.25e-10    2.13e-10
# Accounts_Receivable Common_Stocks                                                 4.16e-12   1.29e-11      0.322      0.748   -2.12e-11    2.95e-11
# Accounts_Receivable Cost_of_Revenue                                             -5.773e-13   3.15e-12     -0.183      0.854   -6.75e-12     5.6e-12
# Accounts_Receivable Current_Ratio                                                   0.0025      0.001      2.204      0.028       0.000       0.005
# Accounts_Receivable Deferred_Asset_Charges                                      -4.313e-11   5.66e-11     -0.761      0.447   -1.54e-10     6.8e-11
# Accounts_Receivable Deferred_Liability_Charges                                   4.425e-11   3.99e-11      1.110      0.267    -3.4e-11    1.22e-10
# Accounts_Receivable Depreciation                                                -1.478e-10   9.44e-11     -1.565      0.118   -3.33e-10    3.75e-11
# Accounts_Receivable Earnings_Before_Interest_and_Tax                            -1.264e-10   1.61e-10     -0.787      0.431   -4.42e-10    1.89e-10
# Accounts_Receivable Earnings_Before_Tax                                          1.146e-10   1.63e-10      0.702      0.483   -2.06e-10    4.35e-10
# Accounts_Receivable Effect_of_Exchange_Rate                                     -4.658e-10   5.26e-10     -0.885      0.376    -1.5e-09    5.67e-10
# Accounts_Receivable Equity_Earnings_Loss_Unconsolidated_Subsidiary               1.849e-10   2.09e-10      0.887      0.376   -2.24e-10    5.94e-10
# Accounts_Receivable Fixed_Assets                                                -1.088e-11   1.32e-11     -0.824      0.410   -3.68e-11     1.5e-11
# Accounts_Receivable Goodwill                                                    -7.878e-12   1.32e-11     -0.599      0.550   -3.37e-11    1.79e-11
# Accounts_Receivable Gross_Margin                                                    0.0068      0.003      2.173      0.030       0.001       0.013
# Accounts_Receivable Gross_Profit                                                 1.374e-11   1.22e-11      1.127      0.260   -1.02e-11    3.77e-11
# Accounts_Receivable Income_Tax                                                  -7.066e-11   1.63e-10     -0.434      0.664    -3.9e-10    2.49e-10
# Accounts_Receivable Intangible_Assets                                            2.728e-11   1.95e-11      1.397      0.163    -1.1e-11    6.56e-11
# Addl_income_expense_items^2                                                     -7.019e-11   4.77e-11     -1.470      0.142   -1.64e-10    2.35e-11
# Addl_income_expense_items After_Tax_ROE                                            -0.0021      0.002     -1.005      0.315      -0.006       0.002
# Addl_income_expense_items Capital_Expenditures                                   1.915e-10   5.82e-11      3.291      0.001    7.73e-11    3.06e-10
# Addl_income_expense_items Capital_Surplus                                       -1.076e-12   1.34e-11     -0.080      0.936   -2.75e-11    2.53e-11
# Addl_income_expense_items Cash_Ratio                                                0.0019      0.002      1.138      0.255      -0.001       0.005
# Addl_income_expense_items Cash_and_Cash_Equivalents                              3.701e-11   3.87e-11      0.956      0.339   -3.89e-11    1.13e-10
# Addl_income_expense_items Changes_in_Inventories                                -3.103e-10   3.37e-10     -0.920      0.358   -9.73e-10    3.52e-10
# Addl_income_expense_items Common_Stocks                                          -2.58e-11   2.62e-11     -0.987      0.324   -7.71e-11    2.55e-11
# Addl_income_expense_items Cost_of_Revenue                                        2.628e-12   7.35e-12      0.358      0.721   -1.18e-11     1.7e-11
# Addl_income_expense_items Current_Ratio                                            -0.0012      0.002     -0.761      0.447      -0.004       0.002
# Addl_income_expense_items Deferred_Asset_Charges                                -9.221e-11      8e-11     -1.153      0.249   -2.49e-10    6.48e-11
# Addl_income_expense_items Deferred_Liability_Charges                            -2.955e-11   2.04e-11     -1.447      0.148   -6.96e-11    1.05e-11
# Addl_income_expense_items Depreciation                                            6.31e-11   1.08e-10      0.582      0.560    -1.5e-10    2.76e-10
# Addl_income_expense_items Earnings_Before_Interest_and_Tax                      -9.401e-11    2.9e-10     -0.324      0.746   -6.63e-10    4.75e-10
# Addl_income_expense_items Earnings_Before_Tax                                    6.944e-11   2.83e-10      0.246      0.806   -4.85e-10    6.24e-10
# Addl_income_expense_items Effect_of_Exchange_Rate                               -1.221e-09   3.83e-10     -3.187      0.001   -1.97e-09   -4.69e-10
# Addl_income_expense_items Equity_Earnings_Loss_Unconsolidated_Subsidiary         3.088e-10   1.96e-10      1.572      0.116   -7.67e-11    6.94e-10
# Addl_income_expense_items Fixed_Assets                                           3.423e-11   1.22e-11      2.806      0.005    1.03e-11    5.82e-11
# Addl_income_expense_items Goodwill                                               2.703e-11   1.81e-11      1.493      0.136   -8.49e-12    6.26e-11
# Addl_income_expense_items Gross_Margin                                              0.0050      0.004      1.340      0.181      -0.002       0.012
# Addl_income_expense_items Gross_Profit                                           -4.33e-11   1.99e-11     -2.175      0.030   -8.24e-11   -4.24e-12
# Addl_income_expense_items Income_Tax                                            -8.873e-11   1.23e-10     -0.719      0.472   -3.31e-10    1.53e-10
# Addl_income_expense_items Intangible_Assets                                      5.027e-12   2.22e-11      0.226      0.821   -3.85e-11    4.86e-11
# After_Tax_ROE^2                                                                    -0.0005      0.001     -0.975      0.330      -0.002       0.001
# After_Tax_ROE Capital_Expenditures                                                 -0.0010      0.001     -1.472      0.141      -0.002       0.000
# After_Tax_ROE Capital_Surplus                                                   -1.257e-05   2.09e-05     -0.601      0.548   -5.36e-05    2.85e-05
# After_Tax_ROE Cash_Ratio                                                        -9.207e-06   9.19e-06     -1.001      0.317   -2.72e-05    8.83e-06
# After_Tax_ROE Cash_and_Cash_Equivalents                                             0.0001      0.000      0.570      0.569      -0.000       0.000
# After_Tax_ROE Changes_in_Inventories                                               -0.0044      0.001     -3.074      0.002      -0.007      -0.002
# After_Tax_ROE Common_Stocks                                                        -0.0005      0.001     -1.014      0.311      -0.002       0.000
# After_Tax_ROE Cost_of_Revenue                                                       0.0002   7.01e-05      2.663      0.008    4.91e-05       0.000
# After_Tax_ROE Current_Ratio                                                     -8.133e-06   1.15e-05     -0.707      0.480   -3.07e-05    1.44e-05
# After_Tax_ROE Deferred_Asset_Charges                                               -0.0039      0.001     -4.653      0.000      -0.006      -0.002
# After_Tax_ROE Deferred_Liability_Charges                                            0.0003      0.001      0.416      0.677      -0.001       0.001
# After_Tax_ROE Depreciation                                                         -0.0013      0.001     -1.882      0.060      -0.003     5.5e-05
# After_Tax_ROE Earnings_Before_Interest_and_Tax                                     -0.0018      0.002     -1.075      0.283      -0.005       0.001
# After_Tax_ROE Earnings_Before_Tax                                                   0.0024      0.002      1.338      0.181      -0.001       0.006
# After_Tax_ROE Effect_of_Exchange_Rate                                              -0.0013      0.004     -0.353      0.724      -0.009       0.006
# After_Tax_ROE Equity_Earnings_Loss_Unconsolidated_Subsidiary                       -0.0067      0.004     -1.677      0.094      -0.015       0.001
# Cash_Ratio Deferred_Liability_Charges                                               0.0001      0.000      0.281      0.779      -0.001       0.001
# Cash_Ratio Depreciation                                                             0.0029      0.001      2.160      0.031       0.000       0.006
# Cash_Ratio Earnings_Before_Interest_and_Tax                                        -0.0047      0.003     -1.721      0.086      -0.010       0.001
# Cash_Ratio Earnings_Before_Tax                                                      0.0047      0.003      1.736      0.083      -0.001       0.010
# Cash_Ratio Effect_of_Exchange_Rate                                                  0.0013      0.006      0.220      0.826      -0.010       0.013
# Cash_Ratio Equity_Earnings_Loss_Unconsolidated_Subsidiary                          -0.0077      0.005     -1.627      0.104      -0.017       0.002
# Cash_Ratio Fixed_Assets                                                             0.0004      0.000      2.452      0.014    8.49e-05       0.001
# Cash_Ratio Goodwill                                                                 0.0003      0.000      1.961      0.050   -1.87e-07       0.001
# Cash_Ratio Gross_Margin                                                         -5.412e-06   6.13e-06     -0.883      0.377   -1.74e-05    6.61e-06
# Cash_Ratio Gross_Profit                                                            -0.0005      0.000     -2.751      0.006      -0.001      -0.000
# Cash_Ratio Income_Tax                                                               0.0026      0.002      1.576      0.115      -0.001       0.006
# Cash_Ratio Intangible_Assets                                                       -0.0007      0.000     -2.265      0.024      -0.001      -9e-05
# Cash_and_Cash_Equivalents^2                                                     -6.383e-12   5.08e-12     -1.257      0.209   -1.63e-11    3.58e-12
# Cash_and_Cash_Equivalents Changes_in_Inventories                                -7.432e-11    5.4e-11     -1.375      0.169    -1.8e-10    3.17e-11
# Cash_and_Cash_Equivalents Common_Stocks                                          9.178e-12   4.68e-12      1.962      0.050   -2.37e-15    1.84e-11
# Cash_and_Cash_Equivalents Cost_of_Revenue                                        1.173e-12   1.18e-12      0.994      0.320   -1.14e-12    3.49e-12
# Cash_and_Cash_Equivalents Current_Ratio                                            -0.0002      0.000     -0.659      0.510      -0.001       0.000
# Cash_and_Cash_Equivalents Deferred_Asset_Charges                                 3.478e-13   2.05e-11      0.017      0.986   -3.99e-11    4.06e-11
# Cash_and_Cash_Equivalents Deferred_Liability_Charges                            -1.828e-11   1.22e-11     -1.501      0.134   -4.22e-11    5.61e-12
# Cash_and_Cash_Equivalents Depreciation                                          -2.822e-11   2.77e-11     -1.020      0.308   -8.25e-11    2.61e-11
# Cash_and_Cash_Equivalents Earnings_Before_Interest_and_Tax                       8.012e-11   7.54e-11      1.063      0.288   -6.78e-11    2.28e-10
# Cash_and_Cash_Equivalents Earnings_Before_Tax                                   -8.215e-11   7.63e-11     -1.077      0.282   -2.32e-10    6.75e-11
# Cash_and_Cash_Equivalents Effect_of_Exchange_Rate                               -2.223e-10    1.1e-10     -2.015      0.044   -4.39e-10   -5.86e-12
# Cash_and_Cash_Equivalents Equity_Earnings_Loss_Unconsolidated_Subsidiary         2.563e-13   9.12e-11      0.003      0.998   -1.79e-10    1.79e-10
# Cash_and_Cash_Equivalents Fixed_Assets                                          -7.341e-12   4.14e-12     -1.772      0.077   -1.55e-11     7.9e-13
# Cash_and_Cash_Equivalents Goodwill                                              -9.317e-13   3.71e-12     -0.251      0.802   -8.21e-12    6.35e-12
# Cost_of_Revenue Intangible_Assets                                                 5.75e-13   1.21e-12      0.474      0.636   -1.81e-12    2.96e-12
# Current_Ratio^2                                                                 -7.035e-05   8.26e-05     -0.852      0.394      -0.000    9.17e-05
# Current_Ratio Deferred_Asset_Charges                                                0.0006      0.001      1.179      0.239      -0.000       0.002
# Current_Ratio Deferred_Liability_Charges                                            0.0001      0.000      0.404      0.686      -0.001       0.001
# Current_Ratio Depreciation                                                         -0.0027      0.001     -3.307      0.001      -0.004      -0.001
# Current_Ratio Earnings_Before_Interest_and_Tax                                      0.0011      0.002      0.619      0.536      -0.002       0.004
# Current_Ratio Earnings_Before_Tax                                                  -0.0003      0.002     -0.203      0.839      -0.004       0.003
# Current_Ratio Effect_of_Exchange_Rate                                               0.0061      0.004      1.687      0.092      -0.001       0.013
# Current_Ratio Equity_Earnings_Loss_Unconsolidated_Subsidiary                        0.0019      0.003      0.603      0.547      -0.004       0.008
# Current_Ratio Fixed_Assets                                                         -0.0001      0.000     -0.956      0.339      -0.000       0.000
# Current_Ratio Goodwill                                                             -0.0003      0.000     -1.721      0.086      -0.001    3.54e-05
# Current_Ratio Gross_Margin                                                      -1.824e-05    8.9e-06     -2.049      0.041   -3.57e-05   -7.75e-07
# Current_Ratio Gross_Profit                                                          0.0002      0.000      1.823      0.069   -1.76e-05       0.000
# Current_Ratio Income_Tax                                                           -0.0034      0.001     -2.377      0.018      -0.006      -0.001
# Current_Ratio Intangible_Assets                                                     0.0002      0.000      1.055      0.292      -0.000       0.001
# Deferred_Asset_Charges^2                                                        -2.666e-12   1.79e-11     -0.149      0.882   -3.78e-11    3.25e-11
# Deferred_Asset_Charges Deferred_Liability_Charges                                -9.64e-12   1.81e-11     -0.533      0.594   -4.51e-11    2.58e-11
# Deferred_Asset_Charges Depreciation                                              7.307e-12   6.02e-11      0.121      0.903   -1.11e-10    1.25e-10
# Deferred_Asset_Charges Earnings_Before_Interest_and_Tax                         -5.538e-11   1.49e-10     -0.371      0.711   -3.49e-10    2.38e-10
# Deferred_Asset_Charges Earnings_Before_Tax                                       7.837e-11   1.49e-10      0.526      0.599   -2.14e-10    3.71e-10
# Deferred_Asset_Charges Effect_of_Exchange_Rate                                   2.076e-10   1.85e-10      1.119      0.263   -1.56e-10    5.71e-10
# Deferred_Asset_Charges Equity_Earnings_Loss_Unconsolidated_Subsidiary            2.944e-10   1.96e-10      1.500      0.134   -9.09e-11     6.8e-10
# Deferred_Asset_Charges Fixed_Assets                                             -3.571e-13   7.04e-12     -0.051      0.960   -1.42e-11    1.35e-11
# Deferred_Asset_Charges Goodwill                                                 -1.454e-11   8.48e-12     -1.716      0.087   -3.12e-11    2.09e-12
# Deferred_Asset_Charges Gross_Margin                                                 0.0017      0.002      0.732      0.464      -0.003       0.006
# Deferred_Asset_Charges Gross_Profit                                              6.385e-12   6.91e-12      0.924      0.356   -7.18e-12       2e-11
# Deferred_Asset_Charges Income_Tax                                               -1.636e-11    6.7e-11     -0.244      0.807   -1.48e-10    1.15e-10
# Deferred_Asset_Charges Intangible_Assets                                         2.342e-11   1.45e-11      1.612      0.107   -5.09e-12    5.19e-11
# Earnings_Before_Interest_and_Tax Effect_of_Exchange_Rate                        -6.362e-10   8.54e-10     -0.745      0.457   -2.31e-09    1.04e-09
# Earnings_Before_Interest_and_Tax Equity_Earnings_Loss_Unconsolidated_Subsidiary  2.362e-10   5.91e-10      0.400      0.690   -9.24e-10     1.4e-09
# Earnings_Before_Interest_and_Tax Fixed_Assets                                    1.554e-11   2.12e-11      0.734      0.463    -2.6e-11    5.71e-11
# Earnings_Before_Interest_and_Tax Goodwill                                       -9.623e-11   3.09e-11     -3.116      0.002   -1.57e-10   -3.56e-11
# Earnings_Before_Interest_and_Tax Gross_Margin                                      -0.0005      0.005     -0.098      0.922      -0.010       0.009
# Earnings_Before_Interest_and_Tax Gross_Profit                                   -3.046e-11   2.86e-11     -1.064      0.288   -8.67e-11    2.57e-11
# Earnings_Before_Interest_and_Tax Income_Tax                                     -4.698e-10   3.05e-10     -1.540      0.124   -1.07e-09    1.29e-10
# Earnings_Before_Interest_and_Tax Intangible_Assets                               1.747e-10   4.35e-11      4.012      0.000    8.92e-11     2.6e-10
# Earnings_Before_Tax^2                                                           -7.648e-11   2.57e-10     -0.297      0.766   -5.81e-10    4.28e-10
# Earnings_Before_Tax Effect_of_Exchange_Rate                                      8.883e-10   8.99e-10      0.988      0.323   -8.75e-10    2.65e-09
# Earnings_Before_Tax Equity_Earnings_Loss_Unconsolidated_Subsidiary               1.503e-10   6.17e-10      0.244      0.808   -1.06e-09    1.36e-09
# Earnings_Before_Tax Fixed_Assets                                                 -1.33e-11   2.12e-11     -0.626      0.532    -5.5e-11    2.84e-11
# Earnings_Before_Tax Goodwill                                                     9.033e-11   3.12e-11      2.896      0.004    2.91e-11    1.52e-10
# Earnings_Before_Tax Gross_Margin                                                    0.0002      0.005      0.038      0.970      -0.010       0.010
# Earnings_Before_Tax Gross_Profit                                                 2.636e-11   2.89e-11      0.911      0.362   -3.04e-11    8.31e-11
# Earnings_Before_Tax Income_Tax                                                   4.631e-10   3.07e-10      1.510      0.131   -1.39e-10    1.06e-09
# Earnings_Before_Tax Intangible_Assets                                           -1.503e-10   4.32e-11     -3.477      0.001   -2.35e-10   -6.55e-11
# Effect_of_Exchange_Rate^2                                                        2.323e-09   9.55e-10      2.432      0.015    4.48e-10     4.2e-09
# Effect_of_Exchange_Rate Equity_Earnings_Loss_Unconsolidated_Subsidiary          -8.328e-10   1.16e-09     -0.721      0.471    -3.1e-09    1.43e-09
# Effect_of_Exchange_Rate Fixed_Assets                                             3.954e-11   5.59e-11      0.707      0.480   -7.02e-11    1.49e-10
# Effect_of_Exchange_Rate Goodwill                                                 4.064e-11    6.2e-11      0.655      0.512    -8.1e-11    1.62e-10
# Effect_of_Exchange_Rate Gross_Margin                                                0.0029      0.010      0.289      0.773      -0.017       0.022
# Effect_of_Exchange_Rate Gross_Profit                                            -1.299e-10   5.49e-11     -2.364      0.018   -2.38e-10   -2.21e-11
# Effect_of_Exchange_Rate Income_Tax                                              -6.769e-10   5.16e-10     -1.312      0.190   -1.69e-09    3.36e-10
# Effect_of_Exchange_Rate Intangible_Assets                                        3.985e-10      1e-10      3.984      0.000    2.02e-10    5.95e-10
# Equity_Earnings_Loss_Unconsolidated_Subsidiary^2                                 1.623e-10   1.75e-10      0.926      0.355   -1.82e-10    5.06e-10
# Equity_Earnings_Loss_Unconsolidated_Subsidiary
447
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            19651.306
# Skew:                           2.011   Prob(JB):                         0.00
# Kurtosis:                      21.625   Cond. No.                     3.07e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.07e+16. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# #Select the first 25 variables
# predictors = df.columns[:25].tolist()
# #Count predictors
# num_var = len(predictors)
# #Create every combinations of two variables in the 25 variables list, append to a empty list
# combinations = []
# for i in range(num_var):
#     for j in range(i+1,num_var):
#         combinations.append(predictors[i] + ':' + predictors[j])
# #Append the interaction to the formula
# formula2 = 'Estimated_Shares_Outstanding ~' + ' + '.join(predictors) + '+'
# formula2 = formula2 + '+'.join(combinations)
# formula2
# #Run the ols model
# ols_model = smf.ols(formula=formula2, data = df_plot).fit()
# output = ols_model.summary()
# #Show the output
# output

# %%
#Extract pvalues and coefficients
pvalues = interaction_model.pvalues
coefficients = interaction_model.params
extract = pd.DataFrame({'Coefficient': coefficients,'pvalue': pvalues}).reset_index()
#Check if the output has 326 observations, 25 variables + 300 interactions + intercept
len(extract)
# Out:
# 351

# %% [markdown]
# New OLS regression model built, with interactions between each combination of the first 25 x variables
#
# - 25 predictors
#
# - 300 interactions
#
# - 1 intercept

# %% [markdown]
# ### b. Briefly explain why interaction terms might be important in the context of predicting Estimated Shares Outstanding using fundamental financial metrics.

# %% [markdown]
# - Explored in the beginning, most of these variables are either derived from one another (Gross profit, Revenue, EBIT...) or affected by each other (Asset, Equity, Liabilites and Ratios).
#
# - The size, sector or performance of a company can directly affect these variables, and at different levels of one predictor can further affect another predictor's effect on the dependent variable.
#
# - Thus, including interaction terms can improve the model and the predictive power of the model, and fully capture the effect of each predictor and how they affect one anothers ability to effect the Estimated Shares Outstanding.

# %% [markdown]
# ### 8. Model Evaluation with Interaction Terms: (10pts, 5 pts for each)

# %% [markdown]
# ### c. Evaluate the performance of this new model with interaction terms. Compare it with the performance of the original model without interaction terms using appropriate metrics.
# ### d. Discuss any significant changes in the model's performance or the coefficients of the predictors.

# %%
#Select predictors with pvalues <= 0.05
significant_p = extract[extract['pvalue']<= 0.05]
significant_p
# Out:
#                             index   Coefficient    pvalue
# 6                 Capital_Surplus  5.561340e-02  0.007770
# 13         Deferred_Asset_Charges  2.449754e-01  0.043650
# 21                       Goodwill  6.144835e-02  0.032324
# 25              Intangible_Assets -1.607078e-01  0.000301
# 26             Accounts_Payable^2  4.127589e-12  0.031811
# ..                            ...           ...       ...
# 338         Goodwill Gross_Profit -7.576762e-12  0.002545
# 339           Goodwill Income_Tax  5.109154e-11  0.017565
# 340    Goodwill Intangible_Assets  6.056432e-12  0.012696
# 349  Income_Tax Intangible_Assets -5.084433e-11  0.024529
# 350           Intangible_Assets^2 -6.589287e-12  0.003350
#
# [90 rows x 3 columns]

# %%
# #Calculate RMSE
# predictions_new = ols_model.predict(df[:25])
# residuals = df['Estimated_Shares_Outstanding']-predictions_new
# #Calculate MSE
# mse = np.mean(residuals**2)
# #Calculate RMSE
# rmse = np.sqrt(mse)
# rmse

# %% [markdown]
# ### Model Comparison
#
# Original Model
#
# - R-squared: 0.854
#
# - Adjusted R-squared: 0.846
#
# - F-statistic is 98.4, p-value near 0
#
# - 17 significant predictors at the 0.05 level
#
# - AIC: 5.516e+04
#
# - BIC: 5.554e+04
#
# - RMSE: 3.8e+08
#
# New Model
#
# - R-squared: 0.941
#
# - Adjusted R-squared: 0.923
#
# - F-statistic is 53.66, p-value near 0
#
# - 104 significant coefficients at the 0.05 level, 1 intercept, 10 individual predictors and 93 interaction terms
#
# - AIC: 5.444e+04
#
# - BIC: 5.598e+04
#
# - RMSE: 1.55e+08
#
# ### Summary
#
# The overall comparison of the two models yield a conclusion that the new model with interaction terms indeed has a better performance.
#
# - Better performing Adjusted R-squared
#
# - Lower RMSE
#
# - Both models are good fits based solely on the F-statistic, AIC and BIC does not show much difference, but the predictors that are shown significant are more in the new model, mainly in the interaction terms, showing that the new model captured more of the effects.

# %% [markdown]
# ### 9. FDR Analysis with Interaction Terms: (10pts)
# ### a. Create a histogram of the p-values for the new model including interaction terms. Discuss any noticeable differences from the histogram you created for the original model. (3pts)

# %%
#Plot histogram from the p-values extracted
plt.hist(extract.iloc[1:]['pvalue'], bins=50, edgecolor='black', alpha=0.7)
plt.title("Histogram of p-values")
plt.xlabel("p-value")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Insights
# - The p-values of the new model shows a more obvious right skewed distribution
#
# - Shows more of a spike around 0, indicating stronger discovery.
#
# - The rest of the distribution is closer to an uniform distribution compared to the original model.
#
# - No more spike in the middle and near 1.0

# %% [markdown]
# ### b. Apply the Benjamini-Hochberg (BH) procedure to control the False Discovery Rate (FDR) with a q-value of 0.1. How many significant predictors are identified now, including both main effects and interaction effects? (5pts)

# %%
#Prepare the p-values, excluding the intercept
p = extract.iloc[1:]
#Run the FDR function
fdr(p['pvalue'],0.1,plotit=True)
# Out:
# Alpha: 0.018488280187803664
# 0.018488280187803664

# %%
#Count the true discoveries
true = p[p['pvalue']<=0.02475891657190202]
len(true['pvalue'])
# Out:
# 76

# %% [markdown]
# ### True Discovery Estimate
# - For the new model, under 0.1 q, the true discovery estimate now is 86

# %%
#Create empty list to store the alphas
alphas = []
#Run the sensitivity analysis
for i in q_values:
    alphas.append(fdr(p['pvalue'],i))
#Count the pvalues below threshold to double check
true_counts = []
for i in alphas:
    count = len(p[p['pvalue']<=i])
    true_counts.append(count)
# Out:
# Alpha: 0.0006114423436161905
# Alpha: 0.0016350231834399436
# Alpha: 0.002980162358136629
# Alpha: 0.005116594381783923
# Alpha: 0.007989936541149642
# Alpha: 0.009934949676761314
# Alpha: 0.012696393303400602
# Alpha: 0.015198245612636373
# Alpha: 0.018488280187803664
# Alpha: 0.018488280187803664
# Alpha: 0.018488280187803664
# Alpha: 0.02452871899008225
# Alpha: 0.030005843899905457
# Alpha: 0.0323237949376493
# Alpha: 0.03460624882519178
# Alpha: 0.0384918920032541
# Alpha: 0.04068401912273509
# Alpha: 0.044125232628618484
# Alpha: 0.04794948103920768
# Alpha: 0.05012341015069725
# Alpha: 0.05409919526961928
# Alpha: 0.0600753923206139
# Alpha: 0.0600753923206139
# Alpha: 0.06461791652436487
# Alpha: 0.06908068965568677
# Alpha: 0.06908068965568677
# Alpha: 0.0778529237368054
# Alpha: 0.08651599876539055
# Alpha: 0.08651599876539055
# Alpha: 0.09689429608114623
# Alpha: 0.09858665570373899
# Alpha: 0.1103728346291894
# Alpha: 0.12395091689569014
# Alpha: 0.1275903672712092
# Alpha: 0.1418265481200266
# Alpha: 0.1418265481200266
# Alpha: 0.15358409333105605
# Alpha: 0.15664300571600923
# Alpha: 0.16571624476183014
# Alpha: 0.17244749878184457
# Alpha: 0.18135456721459944
# Alpha: 0.18815837702266022
# Alpha: 0.18999042758809567
# Alpha: 0.19760760917179124
# Alpha: 0.20308132856939903
# Alpha: 0.2118717701395271
# Alpha: 0.2192899874294885
# Alpha: 0.22740513363904202
# Alpha: 0.22740513363904202
# Alpha: 0.23881233408292235
# Alpha: 0.24924532882699113
# Alpha: 0.2598722944286219
# Alpha: 0.26861616339496047
# Alpha: 0.27737870989636376
# Alpha: 0.29161494019150164
# Alpha: 0.29780755357710686
# Alpha: 0.29780755357710686
# Alpha: 0.3239918619353518
# Alpha: 0.339318450778884
# Alpha: 0.3580428625862718
# Alpha: 0.3624105299824826
# Alpha: 0.38582015902443345
# Alpha: 0.39580756184677257
# Alpha: 0.40394659545685774
# Alpha: 0.4103447465760326
# Alpha: 0.4189862895053792
# Alpha: 0.4336271150596326
# Alpha: 0.44691015075183016
# Alpha: 0.4641850423119135
# Alpha: 0.4837449075939326
# Alpha: 0.4837449075939326
# Alpha: 0.5178560911642609
# Alpha: 0.5271625835811948
# Alpha: 0.5495854313078723
# Alpha: 0.560491745121272
# Alpha: 0.5760071445391599
# Alpha: 0.5760071445391599
# Alpha: 0.6019754350282285
# Alpha: 0.6101141218839177
# Alpha: 0.6166877043833783
# Alpha: 0.6381291981456644
# Alpha: 0.6381291981456644
# Alpha: 0.6573558551779521
# Alpha: 0.6644730769496785
# Alpha: 0.6981291545432577
# Alpha: 0.6981291545432577
# Alpha: 0.7303671336935951
# Alpha: 0.7683238691778608
# Alpha: 0.7871057339223566
# Alpha: 0.8075542649481676
# Alpha: 0.8258885066126781
# Alpha: 0.8399772955519096
# Alpha: 0.8627424942742774
# Alpha: 0.8627424942742774
# Alpha: 0.8817571664314321
# Alpha: 0.9034357169437219
# Alpha: 0.9361849281162986
# Alpha: 0.9361849281162986
# Alpha: 0.9595543859402385
# Alpha: 0.9988985962726944

# %%
#Create DataFrame and plot q's against expected true discoveries
df = pd.DataFrame({'q_values': q_values, 'true_discoveries': true_counts})
plt.scatter(df['q_values'],df['true_discoveries'], s=10)
plt.xlabel('qvalues')
plt.ylabel('Estimated True Discoveries')
plt.show()

# %% [markdown]
# ### c. Compare these results with those obtained from the original model. Discuss the impact of including interaction terms on the number of discoveries and the control of the FDR. (2pts)

# %% [markdown]
# ### Insights
# - Comparing the two models results of discoveries under 0.1 q, the model with interaction terms seems to have much more estimated true discoveries than the original model
#
# - Under any other q levels, we can also see that the new model has way more estimated true discoveries, and the trend from the sensitivity analysis seems more smooth, no sudden spikes
#
# - Overall, the new model shows better performance either comparing the fit and explainability of the model, or the robustness of the predictors that are identified as statisticaly significant.
